# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import random
from tensorflow import keras 
from sklearn import preprocessing, model_selection

# %%
X1 =  (np.tan(np.log(np.random.random(200))) + np.random.random(200)*100)
plt.plot(X1)

# %%
# граф соседа
X2 = np.tan((np.sin(np.random.random(200))) + np.cos(np.random.random(200)) + 1) 
    
plt.plot(X2)

# %%
X2[0:10]
# Out:
# array([-0.53865975, -1.08780357, -1.8030071 , -0.58734773, -0.79053851,
#        -0.73790041, -0.88139422, -0.78811014, -9.1356331 , -2.67367511])

# %%
X2[0:10].shape
# Out:
# (10,)

# %%
X2[0:10]

x = np.zeros(shape=(190, 10))
y = np.zeros(shape=(190, 1))

for i in range(len(X2) - 10):
    x[i] = list(X2[i:i + 10])
for i in range(10, 200):
    y[i-10] = X2[i]
print(X2)
# Out:
# [-0.53865975 -1.08780357 -1.8030071  -0.58734773 -0.79053851 -0.73790041
#  -0.88139422 -0.78811014 -9.1356331  -2.67367511 -0.75382294 -1.68914392
#  -1.73558328 -0.54274849 -1.85766302 -4.6933533  -1.30097187 -0.37114631
#  -1.21288474 -2.06228441 -1.0264093  -0.8679266  -0.60253763 -0.70061578
#  -2.52422721 -1.31985101 -0.71457361 -0.59533072 -1.6297868  -0.33425567
#  -0.391408   -0.83291521 -0.96766456 -0.76559718 -2.67372068 -1.05261934
#  -2.34561583 -0.71794196 -1.06640373 -1.83925124 -0.63313805 -0.93714681
#  -0.87809004 -1.93859675 -1.15932539 -2.09368888 -1.4943387  -0.43342903
#  -3.16263433 -2.13425805 -0.40368852 -2.07579402 -0.95189163 -0.37425873
#  -1.25106109 -1.56387688 -1.63287468 -1.71200657 -1.9614346  -0.39532002
#  -0.52278015 -1.85888764 -1.12857676 -0.90984292 -2.17375504 -1.14205257
#  -0.82457334 -1.72038281 -1.18002884 -1.34045556 -1.70258465 -1.74154549
#  -2.41435181 -0.57003511 -0.94217281 -0.68746458 -1.03015164 -4.84738344
# ...

# %%
model = tf.keras.models.Sequential() 
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(256, activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(512, activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(1, activation = None))

optim = tf.keras.optimizers.SGD()

model.compile(optimizer = optim,
             loss = 'MSE',
             metrics=['MAPE'],
             )

model.fit(x, y, epochs = 200, batch_size = 10)
# Out:
# Epoch 1/200
# 19/19 [==============================] - 1s 3ms/step - loss: 1.3246 - MAPE: 70.5147
# Epoch 2/200
# 19/19 [==============================] - 0s 4ms/step - loss: 1.1637 - MAPE: 68.7667
# Epoch 3/200
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1602 - MAPE: 70.3118
# Epoch 4/200
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0924 - MAPE: 69.9188
# Epoch 5/200
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1049 - MAPE: 70.2870
# Epoch 6/200
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1062 - MAPE: 67.9448
# Epoch 7/200
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0255 - MAPE: 67.2034
# Epoch 8/200
# 19/19 [==============================] - 0s 4ms/step - loss: 1.0459 - MAPE: 74.2008
# Epoch 9/200
# 19/19 [==============================] - 0s 2ms/step - loss: 1.0118 - MAPE: 68.9290
# Epoch 10/200
# ...

# %%
plt.plot(model.predict(x))
plt.plot(X2[10:])
# Out:
# 6/6 [==============================] - 0s 3ms/step

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, train_size=0.7)

# %%
model = tf.keras.models.Sequential() 
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(256, activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(512, activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(1, activation = None))

optim = tf.keras.optimizers.SGD()

model.compile(optimizer = optim,
             loss = 'MSE',
             metrics=['MAPE'],
             )

model.fit(x_train, y_train, epochs = 1000, batch_size = 10)
# Out:
# Epoch 1/1000
# 14/14 [==============================] - 1s 3ms/step - loss: 1.3251 - MAPE: 73.0923
# Epoch 2/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2142 - MAPE: 78.4782
# Epoch 3/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 1.1407 - MAPE: 67.5284
# Epoch 4/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 1.0723 - MAPE: 68.5733
# Epoch 5/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 1.1502 - MAPE: 68.6514
# Epoch 6/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 1.0076 - MAPE: 63.5447
# Epoch 7/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0294 - MAPE: 71.3807
# Epoch 8/1000
# 14/14 [==============================] - 0s 3ms/step - loss: 1.0357 - MAPE: 65.8157
# Epoch 9/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 1.0249 - MAPE: 69.4895
# Epoch 10/1000
# ...

# %%
score, acc = model.evaluate(x_test, y_test)
# Out:
# 2/2 [==============================] - 0s 12ms/step - loss: 1.9261 - MAPE: 97.3118

# %%
x_train = x[0:160]
x_test = x[160:191]
y_train = y[0:160]
y_test = y[160:191]

# %%
model = tf.keras.models.Sequential() 
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(256, activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(512, activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(1, activation = None))

optim = tf.keras.optimizers.SGD()

model.compile(optimizer = optim,
             loss = 'MSE',
             metrics=['MAPE'],
             )

model.fit(x_train, y_train, epochs = 1765, batch_size = 10)
# Out:
# Epoch 1/1765
# 16/16 [==============================] - 1s 5ms/step - loss: 1.2693 - MAPE: 77.5004
# Epoch 2/1765
# 16/16 [==============================] - 0s 5ms/step - loss: 1.0672 - MAPE: 71.6930
# Epoch 3/1765
# 16/16 [==============================] - 0s 5ms/step - loss: 1.0013 - MAPE: 66.9323
# Epoch 4/1765
# 16/16 [==============================] - 0s 5ms/step - loss: 0.9973 - MAPE: 67.4120
# Epoch 5/1765
# 16/16 [==============================] - 0s 6ms/step - loss: 0.9232 - MAPE: 69.3410
# Epoch 6/1765
# 16/16 [==============================] - 0s 5ms/step - loss: 0.9253 - MAPE: 69.4112
# Epoch 7/1765
# 16/16 [==============================] - 0s 5ms/step - loss: 0.9512 - MAPE: 66.5566
# Epoch 8/1765
# 16/16 [==============================] - 0s 5ms/step - loss: 0.9438 - MAPE: 73.4250
# Epoch 9/1765
# 16/16 [==============================] - 0s 5ms/step - loss: 0.9038 - MAPE: 65.6214
# Epoch 10/1765
# ...

# %%
score, acc = model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 262ms/step - loss: 2.6279 - MAPE: 112.7528

# %%
plt.plot(model.predict(x_test))
plt.plot(y_test)
# Out:
# 1/1 [==============================] - 0s 141ms/step

# %%
len(model.predict(x_test))
